# %%
import numpy as np
import csv
import pandas as pd

# %%
 arr=np.array([[0,1,0,2,0,1],[1,0,1,1,2,0],[0,0,2,0,0,1]])

# %%
def analyze_tf(arr, binary=False):
    
    tf_idf=None
    
    # add your code
    if binary==True:
        tf_idf=np.where(arr>=1,1,0)
    #print(tf)
    
    
    return tf_idf

# %%
print(analyze_tf(arr,binary=True))
# Out:
# [[0 1 0 1 0 1]
#  [1 0 1 1 1 0]
#  [0 0 1 0 0 1]]

# %%
n=arr.shape[0]
print(n)
# Out:
# 3

# %%
temp=np.sum(arr,axis=1)
print(temp)
temp.shape
print("\n")
print(arr)
arr.shape
print("\n")
result=arr/temp[:,None]
print(result)
# Out:
# [4 5 3]
#
#
# [[0 1 0 2 0 1]
#  [1 0 1 1 2 0]
#  [0 0 2 0 0 1]]
#
#
# [[0.         0.25       0.         0.5        0.         0.25      ]
#  [0.2        0.         0.2        0.2        0.4        0.        ]
#  [0.         0.         0.66666667 0.         0.         0.33333333]]

# %%
df=np.sum(np.where(arr>=1,1,0),axis=0)
print(df)
print(n/df)
# Out:
# [1 1 2 2 1 2]
# [3.  3.  1.5 1.5 3.  1.5]

# %%
def analyze_tf(arr, binary=False):
    
    tf_idf=None
    
    # add your code
    if binary==True:
        arr_b=np.where(arr>=1,1,0)
        temp=np.sum(arr_b,axis=1)
        tf=arr_b/temp[:,None]
        df=np.sum(np.where(arr_b>=1,1,0),axis=0)
        N=arr_b.shape[0]
        idf=N/df
        tf_idf=tf*np.log(idf)
    else:
        temp=np.sum(arr,axis=1)
        tf=arr/temp[:,None]
        df=np.sum(np.where(arr>=1,1,0),axis=0)
        N=arr.shape[0]
        idf=N/df
        tf_idf=tf*np.log(idf)
    
    return tf_idf

# %%
arr=np.array([[0,1,0,2,0,1],[1,0,1,1,2,0],[0,0,2,0,0,1]])
print(arr, binary = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-82d56bdc646c> in <module>()
#       1 arr=np.array([[0,1,0,2,0,1],[1,0,1,1,2,0],[0,0,2,0,0,1]])
# ----> 2 print(arr, binary = False)
#
# TypeError: 'binary' is an invalid keyword argument for this function

# %%
def analyze_tf(arr, binary=False):
    
    tf_idf=None
    
    # add your code
    if binary==True:
        arr_b=np.where(arr>=1,1,0)
        temp=np.sum(arr_b,axis=1)
        tf=arr_b/temp[:,None]
        df=np.sum(np.where(arr_b>=1,1,0),axis=1)
        N=arr_b.shape[0]
        idf=N/df
        tf_idf=np.array([tf*math.log(i) for i in idf])
    else:
        temp=np.sum(arr,axis=1)
        tf=arr/temp[:,None]
        df=np.sum(np.where(arr>=1,1,0),axis=1)
        N=arr.shape[0]
        idf=N/df
        tf_idf=np.array([tf*math.log(i) for i in idf])
    
    return tf_idf

# %%
arr=np.array([[0,1,0,2,0,1],[1,0,1,1,2,0],[0,0,2,0,0,1]])
# Out:
# array([1, 1, 2, 2, 1, 2])

# %%
data=pd.read_csv('cars.csv',header=0)
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %%
data["Brand"]=data.apply(lambda x:x.car.split()[0],axis=1)
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %%
origin=data[data.origin==1]
origin.sort_values(by='mpg',ascending=False).iloc[0:3,[0,8]]
# Out:
#       mpg                  car
# 194  29.0   chevrolet chevette
# 82   28.0      dodge colt (sw)
# 29   28.0  chevrolet vega 2300

# %%
origin=data[data.origin==1].sort_values(by='mpg',ascending=False).iloc[0:3,:].loc[:,['mpg','car']]
origin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-ad3f80b0159f> in <module>()
#       1 origin=data[data.origin==1].sort_values(by='mpg',ascending=False).iloc[0:3,:].loc[:,['mpg','car']]
#       2 origin
# ----> 3 oringin['car']
#
# NameError: name 'oringin' is not defined

# %%
def car_analysis(filepath):
    data=pd.read_csv(filepath,header=0)
    print(data)

# %%
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...
