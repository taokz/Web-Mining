# %%
import numpy as np
a = np.array([[1, 2, 3],[2,3,4],[3,4,5]]) 
a
# Out:
# array([[1, 2, 3],
#        [2, 3, 4],
#        [3, 4, 5]])

# %%
np.argsort(a)
# Out:
# array([[0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2]], dtype=int64)

# %%
np.argsort(a)[:,::-1][0,0:2]
# Out:
# array([2, 1], dtype=int64)
